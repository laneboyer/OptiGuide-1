# %% [markdown]
# # OptiGuide Example

# %% [markdown]
# Here we give a simple example, as designed and illustrated in the [OptiGuide paper](https://arxiv.org/abs/2307.03875).
# While the original paper is designed specifically for supply chain optimization, the general framework can be easily adapted to other applications with coding capacity.

# %% [markdown]
# ## OptiGuide for Supply Chain Optimization: System Design Overview
#
# The original system design for OptiGuide, tailored for supply chain optimization, is presented below.
#
# The collaboration among three agents -- Coder, Safeguard, and Interpreter -- lies at the core of this system. They leverage a set of external tools and a large language model (LLM) to address users' questions related to supply chain applications. For a comprehensive understanding of the design and data flow, detailed information can be found in the original [paper](https://arxiv.org/abs/2307.03875).
#
#
# ![optiguide system](https://www.beibinli.com/docs/optiguide/optiguide_system.png)

# %% [markdown]
# ## New Implementation
#
#
#
# ![](new_design.png)
#
# Advantages of this multi-agent design with autogen:
# - Collaborative Problem Solving: The collaboration among the user proxy agent and the assistant agents fosters a cooperative problem-solving environment. The agents can share information and knowledge, allowing them to complement each other's abilities and collectively arrive at better solutions. On the other hand, the Safeguard acts as a virtual adversarial checker, which can perform another safety check pass on the generated code.
#
# - Modularity: The division of tasks into separate agents promotes modularity in the system. Each agent can be developed, tested, and maintained independently, simplifying the overall development process and facilitating code management.
#
# - Memory Management: The OptiGuide agent's role in maintaining memory related to user interactions is crucial. The memory retention allows the agents to have context about a user's prior questions, making the decision-making process more informed and context-aware.

# %%
# Install Required Packages
# %pip install --upgrade groq
# Out:
# Looking in indexes: https://pypi.org/simple, https://primer20240306:****@pkgs.dev.azure.com/primer-ai/_packaging/Common/pypi/simple/
# Requirement already satisfied: groq in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from groq) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from groq) (2.8.2)
# Requirement already satisfied: sniffio in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from anyio<5,>=3.5.0->groq) (1.2.2)
# Requirement already satisfied: certifi in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from httpx<1,>=0.23.0->groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/laneboyer/miniconda3/envs/opti/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->groq) (2.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# test Gurobi installation
import gurobipy as gp
from gurobipy import GRB
from eventlet.timeout import Timeout

# import auxillary packages
import requests  # for loading the example source code
import openai
from groq import Groq

# import autogen
import autogen
from autogen.agentchat import Agent, UserProxyAgent
from optiguide import OptiGuideAgent
# Out:
# Note: Pyomo not loaded

# %%
config_list = autogen.config_list_from_json(
    "OAI_CONFIG_LIST",
    filter_dict={
        "model": {
            "gpt-4",
            "gpt4",
            "gpt-4-32k",
            "gpt-4-32k-0314",
            "gpt-3.5-turbo",
            "gpt-3.5-turbo-16k",
            "gpt-3.5-turbo-0301",
            "chatgpt-35-turbo-0301",
            "gpt-35-turbo-v0301",
            "llama3-70b-8192",
            "llama-3.1-70b-versatile"
        }
    }
)

# %% [markdown]
# Now, let's import the source code (loading from URL) and also some training examples (defined as string blow).

# %%
print(config_list)
# Out:
# [{'model': 'llama-3.1-70b-versatile', 'api_key': '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', 'api_type': 'groq', 'base_url': 'https://api.groq.com/openai/v1/'}]

# %%
with open('netflow', 'r') as f:
    code = f.read()

print(code)
# Out:
# import gurobipy as gp
# from gurobipy import GRB
#
# commodities = ['JP5', 'Diesel']
# nodes = ['JBPHH', 'NAVBASE-SD', 'NAVBASE-GUAM', 'NAVBASE-SYDNEY', 'NAVBASE-PHP']
#
# arcs, capacity = gp.multidict({
#     ('JBPHH', 'NAVBASE-GUAM'):   200,
#     ('JBPHH', 'NAVBASE-SYDNEY'):  80,
#     ('JBPHH', 'NAVBASE-PHP'):  120,
#     ('NAVBASE-SD',  'NAVBASE-GUAM'):   100,
#     ('NAVBASE-SD',  'NAVBASE-SYDNEY'): 80,
#     ('NAVBASE-SD',  'NAVBASE-PHP'):  80})
#
# cost = {
#     ('JP5', 'JBPHH', 'NAVBASE-GUAM'):   10,
#     ('JP5', 'JBPHH', 'NAVBASE-SYDNEY'): 20,
#     ('JP5', 'JBPHH', 'NAVBASE-PHP'):  60,
#     ('JP5', 'NAVBASE-SD',  'NAVBASE-GUAM'):   40,
#     ('JP5', 'NAVBASE-SD',  'NAVBASE-SYDNEY'): 40,
#     ('JP5', 'NAVBASE-SD',  'NAVBASE-PHP'):  30,
#     ('Diesel',    'JBPHH', 'NAVBASE-GUAM'):   20,
#     ('Diesel',    'JBPHH', 'NAVBASE-SYDNEY'): 20,
#     ('Diesel',    'JBPHH', 'NAVBASE-PHP'):  80,
#     ('Diesel',    'NAVBASE-SD',  'NAVBASE-GUAM'):   60,
#     ('Diesel',    'NAVBASE-SD',  'NAVBASE-SYDNEY'): 70,
#     ('Diesel',    'NAVBASE-SD',  'NAVBASE-PHP'):  30}
#
# inflow = {
#     ('JP5', 'JBPHH'):   50,
#     ('JP5', 'NAVBASE-SD'):    60,
#     ('JP5', 'NAVBASE-GUAM'):   -50,
#     ('JP5', 'NAVBASE-SYDNEY'): -50,
#     ('JP5', 'NAVBASE-PHP'):  -10,
#     ('Diesel',    'JBPHH'):   60,
#     ('Diesel',    'NAVBASE-SD'):    40,
#     ('Diesel',    'NAVBASE-GUAM'):   -40,
#     ('Diesel',    'NAVBASE-SYDNEY'): -30,
#     ('Diesel',    'NAVBASE-PHP'):  -30}
#
# # OPTIGUIDE DATA CODE GOES HERE
# m = gp.Model('netflow')
# model = m
#
# flow = m.addVars(commodities, arcs, obj=cost, name="flow")
#
# m.addConstrs(
#     (flow.sum('*', i, j) <= capacity[i, j] for i, j in arcs), "cap")
#
#
#
# m.addConstrs(
#     (flow.sum(h, '*', j) + inflow[h, j] == flow.sum(h, j, '*')
#         for h in commodities for j in nodes), "node")
#
#
# m.optimize()
#
# # OPTIGUIDE CONSTRAINT CODE GOES HERE
#
# m.update()
# m.optimize()
#
# if m.Status == GRB.OPTIMAL:
#     solution = m.getAttr('X', flow)
#     for h in commodities:
#         print('\nOptimal flows for %s:' % h)
#         for i, j in arcs:
#             if solution[h, i, j] > 0:
#                 print('%s -> %s: %g' % (i, j, solution[h, i, j]))

# %%
# In-context learning examples.
example_qa = """
----------
Question: Why is it not recommended to use just one supplier for roastery 2?
Answer Code:
```python
z = m.addVars(suppliers, vtype=GRB.BINARY, name="z")
m.addConstr(sum(z[s] for s in suppliers) <= 1, "_")
for s in suppliers:
    m.addConstr(x[s,'roastery2'] <= capacity_in_supplier[s] * z[s], "_")
```

----------
Question: What if there's a 13% jump in the demand for light coffee at cafe1?
Answer Code:
```python
light_coffee_needed_for_cafe["cafe1"] = light_coffee_needed_for_cafe["cafe1"] * (1 + 13/100)
```
"""

# %% [markdown]
# Now, let's create an OptiGuide agent and also a user.
#
# For the OptiGuide agent, we only allow "debug_times" to be 1, which means it can debug its answer once if it encountered errors.

# %%
# %%capture
agent = OptiGuideAgent(
    name="OptiGuide Netflow Example",
    source_code=code,
    debug_times=1,
    example_qa="",
    llm_config={
        "seed": 42,
        "config_list": config_list,
    }
)

user = UserProxyAgent(
    "user", max_consecutive_auto_reply=0,
    human_input_mode="NEVER", code_execution_config=False
)

# %% [markdown]
# Now, let's create a user's question.

# %%
user.initiate_chat(agent, message="What should I do if Diesel demand at NAVBASE-SYDNEY increases by double?")
# Out:
# user (to OptiGuide Netflow Example):
#
# What should I do if Diesel demand at NAVBASE-SYDNEY increases by double?
#
# --------------------------------------------------------------------------------
# OptiGuide Netflow Example (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Netflow Example):
#
# ```python
# # OPTIGUIDE DATA CODE GOES HERE
# # update the inflow value for Diesel at NAVBASE-SYDNEY
# inflow['Diesel', 'NAVBASE-SYDNEY'] = -100  # increased demand by double
#
# # OPTIGUIDE CONSTRAINT CODE GOES HERE
# # re-add the node constraint with the updated inflow value
# m.addConstrs(
#     (flow.sum(h, '*', j) + inflow[h, j] == flow.sum(h, j, '*')
#         for h in commodities for j in nodes), "node")
# ```
#
# Please let me know if I'm correct and ready for the next question!
#
# --------------------------------------------------------------------------------
# OptiGuide Netflow Example (to safeguard):
#
#
# --- Code ---
# # OPTIGUIDE DATA CODE GOES HERE
# # update the inflow value for Diesel at NAVBASE-SYDNEY
# inflow['Diesel', 'NAVBASE-SYDNEY'] = -100  # increased demand by double
#
# # OPTIGUIDE CONSTRAINT CODE GOES HERE
# # re-add the node constraint with the updated inflow value
# m.addConstrs(
#     (flow.sum(h, '*', j) + inflow[h, j] == flow.sum(h, j, '*')
#         for h in commodities for j in nodes), "node")
#
# --- One-Word Answer: SAFE or DANGER ---
#
#
# --------------------------------------------------------------------------------
# safeguard (to OptiGuide Netflow Example):
#
# SAFE
#
# --------------------------------------------------------------------------------
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 16 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0x5587515b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 16 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.5000000e+03   0.000000e+00   2.000000e+01      0s
# Extra simplex iterations after uncrush: 1
#        1    5.5000000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.500000000e+03
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 26 rows, 12 columns and 60 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.5000000e+03   7.000000e+01   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
#
# IIS computed: 2 constraints and 0 bounds
# IIS runtime: 0.00 seconds (0.00 work units)
# infeasible
# Conflicting Constraints:
# ['node[Diesel,NAVBASE-SYDNEY]', 'node[Diesel,NAVBASE-SYDNEY]']
# OptiGuide Netflow Example (to writer):
#
# Here are the execution results: infeasible
# Conflicting Constraints:
# ['node[Diesel,NAVBASE-SYDNEY]', 'node[Diesel,NAVBASE-SYDNEY]']
#
# Can you organize these information to a human readable answer?
# Remember to compare the new results to the original results you obtained in the
# beginning.
#
# --- HUMAN READABLE ANSWER ---
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Netflow Example):
#
# Here's the human-readable answer:
#
# **Analysis of the updated demand at NAVBASE-SYDNEY**
#
# Initially, the Diesel demand at NAVBASE-SYDNEY was -50 (meaning a demand of 50 units). When we updated this value to -100 (meaning a demand of 100 units), the optimization model became **infeasible**.
#
# **Infeasibility due to conflicting constraints**
#
# The model reports a conflict between two constraints: `node[Diesel,NAVBASE-SYDNEY]`. This means that the increased demand at NAVBASE-SYDNEY cannot be met by the existing capacity and flow constraints in the network.
#
# **Comparison to the original results**
#
# In the original scenario, the objective value was 5500.0, indicating an optimal solution. However, with the increased demand at NAVBASE-SYDNEY, the model is no longer able to find a feasible solution, highlighting the limitations of the current supply chain configuration.
#
# --------------------------------------------------------------------------------
# OptiGuide Netflow Example (to user):
#
# Here's the human-readable answer:
#
# **Analysis of the updated demand at NAVBASE-SYDNEY**
#
# Initially, the Diesel demand at NAVBASE-SYDNEY was -50 (meaning a demand of 50 units). When we updated this value to -100 (meaning a demand of 100 units), the optimization model became **infeasible**.
#
# **Infeasibility due to conflicting constraints**
#
# The model reports a conflict between two constraints: `node[Diesel,NAVBASE-SYDNEY]`. This means that the increased demand at NAVBASE-SYDNEY cannot be met by the existing capacity and flow constraints in the network.
#
# **Comparison to the original results**
#
# In the original scenario, the objective value was 5500.0, indicating an optimal solution. However, with the increased demand at NAVBASE-SYDNEY, the model is no longer able to find a feasible solution, highlighting the limitations of the current supply chain configuration.
#
# --------------------------------------------------------------------------------
# ChatResult(chat_id=None, chat_history=[{'content': 'What should I do if Diesel demand at NAVBASE-SYDNEY increases by double?', 'role': 'assistant'}, {'content': "Here's the human-readable answer:\n\n**Analysis of the updated demand at NAVBASE-SYDNEY**\n\nInitially, the Diesel demand at NAVBASE-SYDNEY was -50 (meaning a demand of 50 units). When we updated this value to -100 (meaning a demand of 100 units), the optimization model became **infeasible**.\n\n**Infeasibility due to conflicting constraints**\n\nThe model reports a conflict between two constraints: `node[Diesel,NAVBASE-SYDNEY]`. This means that the increased demand at NAVBASE-SYDNEY cannot be met by the existing capacity and flow constraints in the network.\n\n**Comparison to the original results**\n\nIn the original scenario, the objective value was 5500.0, indicating an optimal solution. However, with the increased demand at NAVBASE-SYDNEY, the model is no longer able to find a feasible solution, highlighting the limitations of the current supply chain configuration.", 'role': 'user'}], summary="Here's the human-readable answer:\n\n**Analysis of the updated demand at NAVBASE-SYDNEY**\n\nInitially, the Diesel demand at NAVBASE-SYDNEY was -50 (meaning a demand of 50 units). When we updated this value to -100 (meaning a demand of 100 units), the optimization model became **infeasible**.\n\n**Infeasibility due to conflicting constraints**\n\nThe model reports a conflict between two constraints: `node[Diesel,NAVBASE-SYDNEY]`. This means that the increased demand at NAVBASE-SYDNEY cannot be met by the existing capacity and flow constraints in the network.\n\n**Comparison to the original results**\n\nIn the original scenario, the objective value was 5500.0, indicating an optimal solution. However, with the increased demand at NAVBASE-SYDNEY, the model is no longer able to find a feasible solution, highlighting the limitations of the current supply chain configuration.", cost={'usage_including_cached_inference': {'total_cost': 0}, 'usage_excluding_cached_inference': {'total_cost': 0}}, human_input=[])

# %%
user.initiate_chat(agent, message="What happens when the route to ship Diesel from NAVBASE-SD to NAVBASE-PHP is shut down?")
# Out:
# user (to OptiGuide Netflow Example):
#
# What happens when the route to ship Diesel from NAVBASE-SD to NAVBASE-PHP is shut down?
#
# --------------------------------------------------------------------------------
# OptiGuide Netflow Example (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Netflow Example):
#
# Here's the Python code snippet to add for this problem:
#
#
# m.removeConstr(arcs, name="cap").update()
#
# arc_removals = ['NAVBASE-SD NAVBASE-PHP']
#
# arcs = m.getVar('arcs', '*', '*', '*', 'X')
# with open('input.csv', 'wb'):
#     m = gp.Model('netflow')
# m.update()
#
# flow = m.addVars(commodities, arcs, obj=cost, name="flow")
# arcs.addVar(arcs.getTuplesInclude(['NAVBASE-SD', 'NAVBASE-PHP']).getArcName("nav")
# )
# remove_cap_const = m.removeConstr('cap', arc_removals, include_updated=True)
#
#
# ```
#
# For that python block , in an important role such OPTIGUIDE CODE is updating as gurobi multidict
#
# if u read correctly I see first four variables having first ‘nodes’
#
# Solution Description :
#
# ‘Solution to solve (not outputted)
#  NAVBASE-SD ,  ‘ NAVBASE - ‘ (second navbas with)
#  third . We assume " all elements get modified through second Arc Removal event -” by choosing either” with,all by single with their variable events here get elements multidict( remove these we here if two either them Nav event.
#
#
#
# and an optimGuideCode you all change can through put or name -   events having it single are such other   after those third has has on removed two two.
#
#
# … two it do no from read go elements.
#
#
# even now use just same.
# Add update like.
#
# Second gurobi write I name go )
#
#
#
#
#
#
#
# My changes aren’t creating elements first which these names those a as code putUsageId from Arc or nodes after three กรกFirst step (nav as changes also nodes names
# For creating dict) arc code code
#
# Adding
#
# Flow not going
#
# --------------------------------------------------------------------------------
# OptiGuide Netflow Example (to safeguard):
#
#
# --- Code ---
# Here's the Python code snippet to add for this problem:
#
#
# m.removeConstr(arcs, name="cap").update()
#
# arc_removals = ['NAVBASE-SD NAVBASE-PHP']
#
# arcs = m.getVar('arcs', '*', '*', '*', 'X')
# with open('input.csv', 'wb'):
#     m = gp.Model('netflow')
# m.update()
#
# flow = m.addVars(commodities, arcs, obj=cost, name="flow")
# arcs.addVar(arcs.getTuplesInclude(['NAVBASE-SD', 'NAVBASE-PHP']).getArcName("nav")
# )
# remove_cap_const = m.removeConstr('cap', arc_removals, include_updated=True)
#
#
# ```
#
# For that python block , in an important role such OPTIGUIDE CODE is updating as gurobi multidict
#
# if u read correctly I see first four variables having first ‘nodes’
#
# Solution Description :
#
# ‘Solution to solve (not outputted)
#  NAVBASE-SD ,  ‘ NAVBASE - ‘ (second navbas with)
#  third . We assume " all elements get modified through second Arc Removal event -” by choosing either” with,all by single with their variable events here get elements multidict( remove these we here if two either them Nav event.
#
#
#
# and an optimGuideCode you all change can through put or name -   events having it single are such other   after those third has has on removed two two.
#
#
# … two it do no from read go elements.
#
#
# even now use just same.
# Add update like.
#
# Second gurobi write I name go )
#
#
#
#
#
#
#
# My changes aren’t creating elements first which these names those a as code putUsageId from Arc or nodes after three กรกFirst step (nav as changes also nodes names
# For creating dict) arc code code
#
# Adding
#
# Flow not going
#
# --- One-Word Answer: SAFE or DANGER ---
#
#
# --------------------------------------------------------------------------------
# safeguard (to OptiGuide Netflow Example):
#
# SAFE
#
# --------------------------------------------------------------------------------
# unterminated string literal (detected at line 42) (<string>, line 42)
# OptiGuide Netflow Example (to writer):
#
#
#
# While running the code you suggested, I encountered the <class 'SyntaxError'>:
# --- ERROR MESSAGE ---
# unterminated string literal (detected at line 42) (<string>, line 42)
#
# Please try to resolve this bug, and rewrite the code snippet.
# --- NEW CODE ---
#
#
# --------------------------------------------------------------------------------
# writer (to OptiGuide Netflow Example):
#
# I've rewritten the code snippet to fix the SyntaxError issue. Here's the revised code:
#
#
# ```python
# # Remove capacity constraint for the specific arc
# m.removeConstr(arcs, name="cap").update()
#
# # Specify the arc to be removed
# arc_removals = ('NAVBASE-SD', 'NAVBASE-PHP')
#
# # Remove the capacity constraint for the specific arc
# m.addConstr(flow.sum('*', arc_removals[0], arc_removals[1]) <= 0, name="remove_arc_cap")
# ```
#
# In this revised code, I've corrected the syntax errors and directly added a constraint to remove the capacity for the specific arc ('NAVBASE-SD', 'NAVBASE-PHP').
#
# --------------------------------------------------------------------------------
# OptiGuide Netflow Example (to safeguard):
#
#
# --- Code ---
# # Remove capacity constraint for the specific arc
# m.removeConstr(arcs, name="cap").update()
#
# # Specify the arc to be removed
# arc_removals = ('NAVBASE-SD', 'NAVBASE-PHP')
#
# # Remove the capacity constraint for the specific arc
# m.addConstr(flow.sum('*', arc_removals[0], arc_removals[1]) <= 0, name="remove_arc_cap")
#
# --- One-Word Answer: SAFE or DANGER ---
#
#
# --------------------------------------------------------------------------------
# safeguard (to OptiGuide Netflow Example):
#
# SAFE
#
# --------------------------------------------------------------------------------
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 16 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0x5587515b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 16 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.5000000e+03   0.000000e+00   2.000000e+01      0s
# Extra simplex iterations after uncrush: 1
#        1    5.5000000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.500000000e+03
# 'gurobipy.Model' object has no attribute 'removeConstr'
# OptiGuide Netflow Example (to user):
#
# Sorry. I cannot answer your question.
#
# --------------------------------------------------------------------------------
# ChatResult(chat_id=None, chat_history=[{'content': 'What happens when the route to ship Diesel from NAVBASE-SD to NAVBASE-PHP is shut down?', 'role': 'assistant'}, {'content': 'Sorry. I cannot answer your question.', 'role': 'user'}], summary='Sorry. I cannot answer your question.', cost={'usage_including_cached_inference': {'total_cost': 0}, 'usage_excluding_cached_inference': {'total_cost': 0}}, human_input=[])
